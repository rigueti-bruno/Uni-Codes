# %% [markdown]
# ### Utilizando o Framework Gensim para PLN

# %% [markdown]
# Incorporações de palavras com Word2Vec

# %%
from gensim.models import Word2Vec
frases = [["laranja", "é", "uma", "fruta"], ["banana", "também", "é", "uma", "fruta"]]
modelo = Word2Vec(frases, vector_size=100, window=5, min_count=1, sg=0)
vetor = modelo.wv["laranja"]
print(vetor)
# Out:
# [-8.7274825e-03  2.1301615e-03 -8.7354420e-04 -9.3190884e-03
#  -9.4281426e-03 -1.4107180e-03  4.4324086e-03  3.7040710e-03
#  -6.4986930e-03 -6.8730675e-03 -4.9994122e-03 -2.2868442e-03
#  -7.2502876e-03 -9.6033178e-03 -2.7436293e-03 -8.3628409e-03
#  -6.0388758e-03 -5.6709289e-03 -2.3441375e-03 -1.7069972e-03
#  -8.9569986e-03 -7.3519943e-04  8.1525063e-03  7.6904297e-03
#  -7.2061159e-03 -3.6668312e-03  3.1185520e-03 -9.5707225e-03
#   1.4764392e-03  6.5244664e-03  5.7464195e-03 -8.7630618e-03
#  -4.5171441e-03 -8.1401607e-03  4.5956374e-05  9.2636338e-03
#   5.9733056e-03  5.0673080e-03  5.0610625e-03 -3.2429171e-03
#   9.5521836e-03 -7.3564244e-03 -7.2703874e-03 -2.2653891e-03
#  -7.7856064e-04 -3.2161034e-03 -5.9258583e-04  7.4888230e-03
#  -6.9751858e-04 -1.6249407e-03  2.7443992e-03 -8.3591007e-03
#   7.8558037e-03  8.5361041e-03 -9.5840869e-03  2.4462664e-03
#   9.9049713e-03 -7.6658037e-03 -6.9669187e-03 -7.7365171e-03
#   8.3959233e-03 -6.8133592e-04  9.1444086e-03 -8.1582209e-03
#   3.7430846e-03  2.6350426e-03  7.4271322e-04  2.3276759e-03
#  -7.4690939e-03 -9.3583735e-03  2.3545765e-03  6.1484552e-03
#   7.9856887e-03  5.7358947e-03 -7.7733636e-04  8.3061643e-03
#  -9.3363142e-03  3.4061326e-03  2.6675343e-04  3.8572443e-03
#   7.3857834e-03 -6.7251669e-03  5.5844807e-03 -9.5222248e-03
#  -8.0445886e-04 -8.6887367e-03 -5.0986730e-03  9.2892265e-03
#  -1.8582619e-03  2.9144264e-03  9.0712793e-03  8.9381328e-03
#  -8.2084350e-03 -3.0123137e-03  9.8866057e-03  5.1044310e-03
#  -1.5880871e-03 -8.6920215e-03  2.9615164e-03 -6.6758976e-03]

# %% [markdown]
# Similaridade de documentos com consultas de similaridade

# %%
from gensim.models import Word2Vec
from gensim.similarities import SoftCosineSimilarity
modelo = Word2Vec.load("word2vec.model")
indice = SoftCosineSimilarity(modelo.wv)
semelhanca = indice[["laranja", "é", "uma", "fruta"], ["banana", "também", "é", "uma", "fruta"]]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 from gensim.models import Word2Vec
#       2 from gensim.similarities import SoftCosineSimilarity
# ----> 3 modelo = Word2Vec.load("word2vec.model")
#       4 indice = SoftCosineSimilarity(modelo.wv)
#       5 semelhanca = indice[["laranja", "é", "uma", "fruta"], ["banana", "também", "é", "uma", "fruta"]]
#
# File ~/.venvs/ml/lib/python3.13/site-packages/gensim/models/word2vec.py:1953, in Word2Vec.load(cls, rethrow, *args, **kwargs)
#    1934 """Load a previously saved :class:`~gensim.models.word2vec.Word2Vec` model.
#    1935
#    1936 See Also
#    (...)   1950
#    1951 """
#    1952 try:
# -> 1953     model = super(Word2Vec, cls).load(*args, **kwargs)
#    1954     if not isinstance(model, Word2Vec):
#    1955         rethrow = True
#
# File ~/.venvs/ml/lib/python3.13/site-packages/gensim/utils.py:485, in SaveLoad.load(cls, fname, mmap)
#     481 logger.info("loading %s object from %s", cls.__name__, fname)
#     483 compress, subname = SaveLoad._adapt_by_suffix(fname)
# --> 485 obj = unpickle(fname)
#     486 obj._load_specials(fname, mmap, compress, subname)
#     487 obj.add_lifecycle_event("loaded", fname=fname)
#
# File ~/.venvs/ml/lib/python3.13/site-packages/gensim/utils.py:1459, in unpickle(fname)
#    1445 def unpickle(fname):
#    1446     """Load object from `fname`, using smart_open so that `fname` can be on S3, HDFS, compressed etc.
#    1447
#    1448     Parameters
#    (...)   1457
#    1458     """
# -> 1459     with open(fname, 'rb') as f:
#    1460         return _pickle.load(f, encoding='latin1')
#
# File ~/.venvs/ml/lib/python3.13/site-packages/smart_open/smart_open_lib.py:170, in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, compression, transport_params)
#     167 if transport_params is None:
#     168     transport_params = {}
# --> 170 fobj = _shortcut_open(
#     171     uri,
#     172     mode,
#     173     compression=compression,
#     174     buffering=buffering,
#     175     encoding=encoding,
#     176     errors=errors,
#     177     newline=newline,
#     178 )
#     179 if fobj is not None:
#     180     return fobj
#
# File ~/.venvs/ml/lib/python3.13/site-packages/smart_open/smart_open_lib.py:368, in _shortcut_open(uri, mode, compression, buffering, encoding, errors, newline)
#     365 if errors and 'b' not in mode:
#     366     open_kwargs['errors'] = errors
# --> 368 return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'word2vec.model'

# %% [markdown]
# Modelagem de tópicos com alocação de Dirichlet latente (LDA)

# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary
texto = [["laranja", "é", "uma", "fruta"], ["banana", "também", "é", "uma", "fruta"]]
dicionario = Dictionary(texto)
corpus = [dicionario.doc2bow(palavra) for palavra in texto]
modelo = LdaModel(corpus, num_topics=2, id2word=dicionario)
for i in modelo.print_topics():
    print(i)
# Out:
# (0, '0.182*"fruta" + 0.176*"é" + 0.170*"banana" + 0.168*"uma" + 0.166*"também" + 0.138*"laranja"')
# (1, '0.213*"uma" + 0.210*"é" + 0.207*"fruta" + 0.131*"laranja" + 0.120*"também" + 0.118*"banana"')
